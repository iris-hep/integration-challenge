# %% [markdown]
# # CMS search for a Z' boson in the single-lepton channel with full Run 2 dataset (with metrics dashboards)
#
# This notebook demonstrates the Z' → tt̄ single-lepton analysis workflow on various AFs, including skimming, analysis, histogramming, and statistics steps.
#
# This version includes performance metrics collected with [roastcoffea](https://github.com/MoAly98/roastcoffea), a toolkit for benchmarking and profiling coffea-based HEP
# analysis workflows.

# %% [markdown]
# ## Workflow Overview
#
# 1. Setup Python path for intccms package
# 2. Install dependencies and register modules for cloud pickle
# 3. Acquire Dask client from AF environment
# 4. Configure analysis parameters
# 5. Run metadata extraction (`coffea` preprocessing)
# 6. Initialize analysis processor
# 7. Run processor with coffea.processor.Runner
# 8. Save histograms and run statistical analysis (if enabled)
# 9. Extract and visualize performance metrics with `roastcoffea`

# %% [markdown]
# ## AF flag
# We  want to run this code on different facilities, which may each have their own limitations or require different dask client setups. To make it easy to switch between facilities, just set the `AF` variable to the one of your choice. If your `AF` does not exist yet, you can introduce it in this notebook in the relevant sections.

# %%
AF="coffeacasa-condor" # options currently supported: [coffeacasa-condor, coffeacasa-gateway, purdue-af-k8s, purdue-af-slurm]
AUTO_CLOSE_CLIENT=False # the client setup is done with a contextmanager -- this flag decides if we automatically close the client as we exit the manager. If False, you handle closing manually.

# %% [markdown]
# ## Imports and dependencies

# %% [markdown]
# ### The intccms package
# The CMS implementation of the integration challenge is set in a package-like structure, which means we hae to add the source code to the python path. The package is referred to as `intccms`.

# %%
# Setup Python path to include intccms package
import sys
from pathlib import Path

# Add src directory to Python path
repo_root = Path.cwd()
src_dir = repo_root / "src"
examples_dir = repo_root
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))
if str(examples_dir) not in sys.path:
    sys.path.insert(0, str(examples_dir))
print(f"✅ Added {src_dir} to Python path")
print(f"✅ Added {examples_dir} to Python path")
# Out:
# ✅ Added /home/cms-jovyan/intc/integration-challenge/cms/src to Python path
# ✅ Added /home/cms-jovyan/intc/integration-challenge/cms to Python path

# %% [markdown]
# ### Installig extra dependencies
# The `intccms` package requires `omegaconf`, which is not by default on an AF.

# %%
try:
    import omegaconf
except ImportError:
    print("⚠️ omegaconf not found, installing...")
    ! pip install omegaconf;
try:
    import roastcoffea
except ImportError:
    print("⚠️ omegaconf not found, installing...")
    ! pip install roastcoffea
    import roastcoffea;

# %% [markdown]
# ### Alternative coffea version
# In some cases, we might need to install our own `coffea` version which is not on the AF. For example, when testing a new feature or using a recently realased version with a fix.

# %%
COFFEA_VERSION = "2026.4.0"
COFFEA_PIP = f"coffea=={COFFEA_VERSION}" if "git" not in COFFEA_VERSION else COFFEA_VERSION

! pip install $COFFEA_PIP;

# Pip-installable dependencies to install on workers
WORKER_DEPENDENCIES = [COFFEA_PIP, "roastcoffea==0.1.2"]
# Out:
# Requirement already satisfied: coffea==2026.4.0 in /usr/local/lib/python3.12/site-packages (2026.4.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (3.13.5)
# Requirement already satisfied: awkward>=2.8.11 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (2.9.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (7.0.5)
# Requirement already satisfied: cloudpickle>=1.2.3 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (3.1.2)
# Requirement already satisfied: correctionlib>=2.6.0 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (2.8.0)
# Requirement already satisfied: dask-awkward>=2025.9.0 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (2026.2.1)
# Requirement already satisfied: dask-histogram>=2025.2.0 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (2026.2.0)
# Requirement already satisfied: dask>=2024.3.0 in /usr/local/lib/python3.12/site-packages (from dask[array]>=2024.3.0->coffea==2026.4.0) (2025.3.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (2026.3.0)
# Requirement already satisfied: hist>=2 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (2.10.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (8.1.8)
# Requirement already satisfied: loky>=3.5.6 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (3.5.6)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (4.4.5)
# Requirement already satisfied: matplotlib>=3 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (3.10.8)
# Requirement already satisfied: mplhep>=0.1.18 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (1.1.2)
# Requirement already satisfied: numba>=0.58.1 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (0.65.0)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (2.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (26.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (2.3.3)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (21.0.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (2.13.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (2.32.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (15.0.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (1.17.1)
# Requirement already satisfied: toml>=0.10.2 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (0.10.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (4.67.3)
# Requirement already satisfied: uproot>=5.7.0 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (5.7.3)
# Requirement already satisfied: vector!=1.6.0,>=1.4.1 in /usr/local/lib/python3.12/site-packages (from coffea==2026.4.0) (1.8.0)
# Requirement already satisfied: awkward-cpp==52 in /usr/local/lib/python3.12/site-packages (from awkward>=2.8.11->coffea==2026.4.0) (52)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/site-packages (from dask>=2024.3.0->dask[array]>=2024.3.0->coffea==2026.4.0) (8.3.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/site-packages (from dask>=2024.3.0->dask[array]>=2024.3.0->coffea==2026.4.0) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/site-packages (from dask>=2024.3.0->dask[array]>=2024.3.0->coffea==2026.4.0) (6.0.3)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.12/site-packages (from dask>=2024.3.0->dask[array]>=2024.3.0->coffea==2026.4.0) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/site-packages (from dask-awkward>=2025.9.0->coffea==2026.4.0) (4.15.0)
# Requirement already satisfied: boost-histogram>=1.3.2 in /usr/local/lib/python3.12/site-packages (from dask-histogram>=2025.2.0->coffea==2026.4.0) (1.7.2)
# Requirement already satisfied: histoprint>=2.2.0 in /usr/local/lib/python3.12/site-packages (from hist>=2->coffea==2026.4.0) (2.6.0)
# Requirement already satisfied: uhi>=0.2.1 in /usr/local/lib/python3.12/site-packages (from histoprint>=2.2.0->hist>=2->coffea==2026.4.0) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3->coffea==2026.4.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3->coffea==2026.4.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3->coffea==2026.4.0) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3->coffea==2026.4.0) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3->coffea==2026.4.0) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3->coffea==2026.4.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3->coffea==2026.4.0) (2.9.0.post0)
# Requirement already satisfied: mplhep-data>=0.0.4 in /usr/local/lib/python3.12/site-packages (from mplhep>=0.1.18->coffea==2026.4.0) (0.0.5)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /usr/local/lib/python3.12/site-packages (from numba>=0.58.1->coffea==2026.4.0) (0.47.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/site-packages (from partd>=1.4.0->dask>=2024.3.0->dask[array]>=2024.3.0->coffea==2026.4.0) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/site-packages (from pydantic->coffea==2026.4.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.0 in /usr/local/lib/python3.12/site-packages (from pydantic->coffea==2026.4.0) (2.46.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/site-packages (from pydantic->coffea==2026.4.0) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3->coffea==2026.4.0) (1.17.0)
# Requirement already satisfied: cramjam>=2.5.0 in /usr/local/lib/python3.12/site-packages (from uproot>=5.7.0->coffea==2026.4.0) (2.11.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/site-packages (from uproot>=5.7.0->coffea==2026.4.0) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/site-packages (from aiohttp->coffea==2026.4.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/site-packages (from aiohttp->coffea==2026.4.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/site-packages (from aiohttp->coffea==2026.4.0) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/site-packages (from aiohttp->coffea==2026.4.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/site-packages (from aiohttp->coffea==2026.4.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/site-packages (from aiohttp->coffea==2026.4.0) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/site-packages (from aiohttp->coffea==2026.4.0) (1.23.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp->coffea==2026.4.0) (3.11)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.12/site-packages (from ipywidgets->coffea==2026.4.0) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.12/site-packages (from ipywidgets->coffea==2026.4.0) (9.12.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/site-packages (from ipywidgets->coffea==2026.4.0) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /usr/local/lib/python3.12/site-packages (from ipywidgets->coffea==2026.4.0) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/lib/python3.12/site-packages (from ipywidgets->coffea==2026.4.0) (3.0.16)
# Requirement already satisfied: decorator>=5.1.0 in /usr/local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->coffea==2026.4.0) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /usr/local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->coffea==2026.4.0) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /usr/local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->coffea==2026.4.0) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /usr/local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->coffea==2026.4.0) (0.2.1)
# Requirement already satisfied: pexpect>4.6 in /usr/local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->coffea==2026.4.0) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->coffea==2026.4.0) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /usr/local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->coffea==2026.4.0) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /usr/local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->coffea==2026.4.0) (0.6.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->coffea==2026.4.0) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets->coffea==2026.4.0) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/site-packages (from pexpect>4.6->ipython>=6.1.0->ipywidgets->coffea==2026.4.0) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->coffea==2026.4.0) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->coffea==2026.4.0) (3.0.1)
# Requirement already satisfied: pure_eval in /usr/local/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->coffea==2026.4.0) (0.2.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/site-packages (from pandas->coffea==2026.4.0) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/site-packages (from pandas->coffea==2026.4.0) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/site-packages (from requests->coffea==2026.4.0) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/site-packages (from requests->coffea==2026.4.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/site-packages (from requests->coffea==2026.4.0) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/site-packages (from rich->coffea==2026.4.0) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->coffea==2026.4.0) (0.1.2)

# %% [markdown]
# ### Imports from stdlib and other libraries
#
# In this notebook we use `dask` and `coffea`.

# %%
# stdlib
import cloudpickle
import copy
import os
import time

from coffea.processor import DaskExecutor, IterativeExecutor
from coffea.nanoevents import NanoAODSchema

# %% [markdown]
# ### Imports from intccms

# %%
# intccms
from intccms.schema import Config, load_config_with_restricted_cli
from intccms.utils.output import OutputDirectoryManager
from intccms.utils.dask_client import acquire_client
from intccms.metadata_extractor import DatasetMetadataManager
from intccms.datasets import DatasetManager
from intccms.analysis import run_processor_workflow

# %% [markdown]
# ### Registering packages with cloudpickle
# The intccms cannot be installed on the workers via `pip`, and the configuration files are in python modules which also cannot be installed on the workers. So we need to register them with `cloudpickle` to allow dask to serialize them and send them out. `roastcoffea` is also currently not avialble on `pip` (wip).

# %%
import intccms
import example_cms

# Register modules for cloud pickle
cloudpickle.register_pickle_by_value(intccms)
cloudpickle.register_pickle_by_value(example_cms)
cloudpickle.register_pickle_by_value(roastcoffea)

# %% [markdown]
# ## Dask client setup
#
# This notebook uses the `DaskExecutor` from `coffea` to distribute the task graph on the AF. The client setup varies in different facilities, so we implement a function which returns the correct client. The function does so by providing a context manager, within which the client is alive.

# %% [markdown]
# ## Configuration Setup
#
# The CMS analysis implementation is configurable via python modules, which we have to import. For this notebook, the configuration files are found in `example_cms/configs/`. You can modify the modules in this directory manually, or you can dynamically change settings using python dictionary manipulation. Below are some settings of interest that you might want to tune when you are testing your setup.

# %%
# intccms configuration import
from example_cms.configs.configuration import config as original_config

# Create a deepcopy that we can manipulate
config = copy.deepcopy(original_config)

config["general"]["fileset_path"] = "example_cms/rntuples.json"

# Limit files for testing
config["datasets"]["max_files"] = None # None would run over all availale files

# Use local output directory
config["general"]["output_dir"] = "example_cms/outputs_rntupl/"

# Preprocessing (coffea) can be executed once and results loaded
# We recommend that on your second run of this notebook, set this to False to save time.
config["general"]["run_metadata_generation"] = True # If True, run analysis pre-processing

# Processer = Skimming (filter and save) + Analysis
config["general"]["run_processor"] = True  # If True, the coffea processor is executed
config["general"]["run_analysis"] = True # If True, the analysis part of the processor is executed
config["general"]["save_skimmed_output"] = False  # If True, skimmed events are saved to disk, otherwise filter executed on-the-fly

# Analysis = Systematics + histogramming + statsitics
config["general"]["run_histogramming"] = True
config["general"]["run_systematics"] = False
config["general"]["run_statistics"] = False

# Datasets to process, by default this is all datasets
#config["general"]["processes"] = ["data"] 

cli_args = [] # the code can be ran from CLI, but we don't care here
full_config = load_config_with_restricted_cli(config, cli_args)

# Validated config gives us a dictionary object with all settings checked to be safe with pydantic
validated_config = Config(**full_config)

# %% [markdown]
# ## Running the Workflow
#
# Running the CMS integration challenge workflow is split into a few steps, with a modular design that allows us flexibility. The steps are:
#
# 1. Setting up output directories
# 2. Building an input dataset manager
# 3. Running or loading the coffea preprocessing
# 4. Run the coffea processor

# %% [markdown]
# ### Output manager setup

# %%
output_manager = OutputDirectoryManager(
    root_output_dir=validated_config.general.output_dir,
    cache_dir=validated_config.general.cache_dir,
    metadata_dir=validated_config.general.metadata_dir,
    skimmed_dir=validated_config.general.skimmed_dir
)
# Out:
# 2026-05-14 22:17:05.496 INFO:intccms.utils.output.directories:Output directory manager initialized with root: /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs

# %% [markdown]
# ## Configure Data Redirector (Optional)
#
# Override the redirector in the config for accessing dataset files. Useful for testing different storage backends. You can also change this in `example_cms/configs/skim.py`

# %%
# Override redirector for all datasets
# Examples:
#   "root://xcache/"                    
#   "root://cmsxrootd.fnal.gov/"
#   "root://cms-xrd-global.cern.ch/"
REDIRECTOR = "root://xcache/"  # Change this to use a different redirector

print(f"Initial redirector  {validated_config.datasets.datasets[0].name}: {validated_config.datasets.datasets[0].redirector}")

# Apply to all datasets in config
for dataset in validated_config.datasets.datasets:
 dataset.redirector = REDIRECTOR

print(f"Redirector set to: {REDIRECTOR}")

# Verify the change
print(f"New redirector:  {validated_config.datasets.datasets[0].name}: {validated_config.datasets.datasets[0].redirector}")
# Out:
# Initial redirector  signal: root://xcache/
# Redirector set to: root://xcache/
# New redirector:  signal: root://xcache/

# %% [markdown]
# ### Input dataset manager setup

# %%
dataset_manager = DatasetManager(validated_config.datasets)
# Out:
# 2026-05-14 22:17:05.519 INFO:intccms.datasets.manager:Initialized dataset manager with 10 datasets

# %% [markdown]
# ### Coffea preprocessing

# %%
metadata_generator = DatasetMetadataManager(
  dataset_manager=dataset_manager,
  output_manager=output_manager,
  config=validated_config,
)

if metadata_generator.generate_metadata:
  with acquire_client(AF) as (client, cluster):
      metadata_generator.run(executor=DaskExecutor(client=client))
else:
  metadata_generator.run()  # No client needed

# Build metadata lookup and extract workitems
metadata_lookup = metadata_generator.build_metadata_lookup()
workitems = metadata_generator.workitems
print(f"Generated {len(workitems)} workitems ...")
# Out:
# Preprocessing 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13757/13757 [ 0:00:25 < 0:00:00 | 558.4 file/s ]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 2026-05-14 22:17:33.524 INFO:intccms.metadata_extractor.extractor:Extracted 36173 WorkItems from 125 datasets
# 2026-05-14 22:17:34.080 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/workitems.json
# 2026-05-14 22:17:34.087 INFO:intccms.metadata_extractor.manager:Aggregating event counts from WorkItems...
# 2026-05-14 22:17:34.262 INFO:intccms.metadata_extractor.manager:Event count summary generated.
# 2026-05-14 22:17:34.308 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods.json
# 2026-05-14 22:17:34.309 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_signal_0_nominal.json
# 2026-05-14 22:17:34.310 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_signal_1_nominal.json
# 2026-05-14 22:17:34.310 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_signal_2_nominal.json
# 2026-05-14 22:17:34.311 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_ttbar_semilep_0_nominal.json
# 2026-05-14 22:17:34.313 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_ttbar_semilep_1_nominal.json
# 2026-05-14 22:17:34.314 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_ttbar_semilep_2_nominal.json
# 2026-05-14 22:17:34.315 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_ttbar_had_0_nominal.json
# 2026-05-14 22:17:34.317 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_ttbar_had_1_nominal.json
# 2026-05-14 22:17:34.318 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_ttbar_had_2_nominal.json
# 2026-05-14 22:17:34.319 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_ttbar_lep_0_nominal.json
# 2026-05-14 22:17:34.320 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_ttbar_lep_1_nominal.json
# 2026-05-14 22:17:34.321 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_ttbar_lep_2_nominal.json
# 2026-05-14 22:17:34.322 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_0_nominal.json
# 2026-05-14 22:17:34.324 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_1_nominal.json
# 2026-05-14 22:17:34.325 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_2_nominal.json
# 2026-05-14 22:17:34.326 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_3_nominal.json
# 2026-05-14 22:17:34.327 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_4_nominal.json
# 2026-05-14 22:17:34.328 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_5_nominal.json
# 2026-05-14 22:17:34.330 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_6_nominal.json
# 2026-05-14 22:17:34.331 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_7_nominal.json
# 2026-05-14 22:17:34.333 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_8_nominal.json
# 2026-05-14 22:17:34.336 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_9_nominal.json
# 2026-05-14 22:17:34.338 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_10_nominal.json
# 2026-05-14 22:17:34.340 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_11_nominal.json
# 2026-05-14 22:17:34.341 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_12_nominal.json
# 2026-05-14 22:17:34.343 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_13_nominal.json
# 2026-05-14 22:17:34.344 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_14_nominal.json
# 2026-05-14 22:17:34.346 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_15_nominal.json
# 2026-05-14 22:17:34.349 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_16_nominal.json
# 2026-05-14 22:17:34.352 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_17_nominal.json
# 2026-05-14 22:17:34.356 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_18_nominal.json
# 2026-05-14 22:17:34.357 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_19_nominal.json
# 2026-05-14 22:17:34.359 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_20_nominal.json
# 2026-05-14 22:17:34.360 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_21_nominal.json
# 2026-05-14 22:17:34.362 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_22_nominal.json
# 2026-05-14 22:17:34.363 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_wjets_23_nominal.json
# 2026-05-14 22:17:34.364 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_0_nominal.json
# 2026-05-14 22:17:34.364 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_1_nominal.json
# 2026-05-14 22:17:34.365 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_2_nominal.json
# 2026-05-14 22:17:34.365 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_3_nominal.json
# 2026-05-14 22:17:34.366 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_4_nominal.json
# 2026-05-14 22:17:34.366 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_5_nominal.json
# 2026-05-14 22:17:34.367 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_6_nominal.json
# 2026-05-14 22:17:34.367 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_7_nominal.json
# 2026-05-14 22:17:34.368 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_8_nominal.json
# 2026-05-14 22:17:34.368 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_9_nominal.json
# 2026-05-14 22:17:34.369 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_10_nominal.json
# 2026-05-14 22:17:34.369 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_11_nominal.json
# 2026-05-14 22:17:34.370 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_12_nominal.json
# 2026-05-14 22:17:34.370 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_13_nominal.json
# 2026-05-14 22:17:34.371 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_14_nominal.json
# 2026-05-14 22:17:34.372 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_15_nominal.json
# 2026-05-14 22:17:34.372 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_16_nominal.json
# 2026-05-14 22:17:34.373 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_17_nominal.json
# 2026-05-14 22:17:34.373 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_18_nominal.json
# 2026-05-14 22:17:34.374 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_19_nominal.json
# 2026-05-14 22:17:34.374 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_20_nominal.json
# 2026-05-14 22:17:34.375 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_21_nominal.json
# 2026-05-14 22:17:34.375 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_22_nominal.json
# 2026-05-14 22:17:34.376 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_dyjets_23_nominal.json
# 2026-05-14 22:17:34.376 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_single_top_0_nominal.json
# 2026-05-14 22:17:34.377 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_single_top_1_nominal.json
# 2026-05-14 22:17:34.377 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_single_top_2_nominal.json
# 2026-05-14 22:17:34.378 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_single_top_3_nominal.json
# 2026-05-14 22:17:34.378 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_single_top_4_nominal.json
# 2026-05-14 22:17:34.379 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_single_top_5_nominal.json
# 2026-05-14 22:17:34.380 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_single_top_6_nominal.json
# 2026-05-14 22:17:34.381 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_single_top_7_nominal.json
# 2026-05-14 22:17:34.381 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_single_top_8_nominal.json
# 2026-05-14 22:17:34.382 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_single_top_9_nominal.json
# 2026-05-14 22:17:34.382 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_single_top_10_nominal.json
# 2026-05-14 22:17:34.383 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_single_top_11_nominal.json
# 2026-05-14 22:17:34.384 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_single_top_12_nominal.json
# 2026-05-14 22:17:34.385 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_single_top_13_nominal.json
# 2026-05-14 22:17:34.385 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_single_top_14_nominal.json
# 2026-05-14 22:17:34.386 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_0_nominal.json
# 2026-05-14 22:17:34.386 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_1_nominal.json
# 2026-05-14 22:17:34.387 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_2_nominal.json
# 2026-05-14 22:17:34.387 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_3_nominal.json
# 2026-05-14 22:17:34.388 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_4_nominal.json
# 2026-05-14 22:17:34.389 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_5_nominal.json
# 2026-05-14 22:17:34.389 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_6_nominal.json
# 2026-05-14 22:17:34.390 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_7_nominal.json
# 2026-05-14 22:17:34.390 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_8_nominal.json
# 2026-05-14 22:17:34.391 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_9_nominal.json
# 2026-05-14 22:17:34.391 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_10_nominal.json
# 2026-05-14 22:17:34.392 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_11_nominal.json
# 2026-05-14 22:17:34.393 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_12_nominal.json
# 2026-05-14 22:17:34.393 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_13_nominal.json
# 2026-05-14 22:17:34.394 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_14_nominal.json
# 2026-05-14 22:17:34.394 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_15_nominal.json
# 2026-05-14 22:17:34.395 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_16_nominal.json
# 2026-05-14 22:17:34.396 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_17_nominal.json
# 2026-05-14 22:17:34.397 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_18_nominal.json
# 2026-05-14 22:17:34.398 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_19_nominal.json
# 2026-05-14 22:17:34.398 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_20_nominal.json
# 2026-05-14 22:17:34.399 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_21_nominal.json
# 2026-05-14 22:17:34.400 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_22_nominal.json
# 2026-05-14 22:17:34.400 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_23_nominal.json
# 2026-05-14 22:17:34.401 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_24_nominal.json
# 2026-05-14 22:17:34.402 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_25_nominal.json
# 2026-05-14 22:17:34.402 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_qcd_26_nominal.json
# 2026-05-14 22:17:34.403 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_diboson_0_nominal.json
# 2026-05-14 22:17:34.403 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_diboson_1_nominal.json
# 2026-05-14 22:17:34.404 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_diboson_2_nominal.json
# 2026-05-14 22:17:34.404 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_diboson_3_nominal.json
# 2026-05-14 22:17:34.404 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_diboson_4_nominal.json
# 2026-05-14 22:17:34.405 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_diboson_5_nominal.json
# 2026-05-14 22:17:34.405 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_diboson_6_nominal.json
# 2026-05-14 22:17:34.406 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_diboson_7_nominal.json
# 2026-05-14 22:17:34.407 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_diboson_8_nominal.json
# 2026-05-14 22:17:34.407 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_data_0_nominal.json
# 2026-05-14 22:17:34.408 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_data_1_nominal.json
# 2026-05-14 22:17:34.408 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_data_2_nominal.json
# 2026-05-14 22:17:34.409 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_data_3_nominal.json
# 2026-05-14 22:17:34.409 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_data_4_nominal.json
# 2026-05-14 22:17:34.410 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_data_5_nominal.json
# 2026-05-14 22:17:34.411 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_data_6_nominal.json
# 2026-05-14 22:17:34.412 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_data_7_nominal.json
# 2026-05-14 22:17:34.412 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_data_8_nominal.json
# 2026-05-14 22:17:34.413 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_data_9_nominal.json
# 2026-05-14 22:17:34.414 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_data_10_nominal.json
# 2026-05-14 22:17:34.415 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_data_11_nominal.json
# 2026-05-14 22:17:34.415 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_data_12_nominal.json
# 2026-05-14 22:17:34.416 INFO:intccms.metadata_extractor.io:Saved JSON to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/metadata/nanoaods_data_13_nominal.json
# 2026-05-14 22:17:34.417 INFO:intccms.metadata_extractor.manager:Metadata generation complete.
# 2026-05-14 22:17:34.417 INFO:intccms.metadata_extractor.manager:Built metadata lookup for 125 fileset keys
# Generated 36173 workitems ...

# %% [markdown]
# ### Run Analysis processor

# %%
# Run processor workflow with roastcoffea metrics collection
from roastcoffea import MetricsCollector
from intccms.analysis.processors import SkimAndAnalyseProcessor

with acquire_client(AF) as (client, cluster):
    # Create processor instance for MetricsCollector
    unified_processor = SkimAndAnalyseProcessor(
        config=validated_config,
        output_manager=output_manager,
        metadata_lookup=metadata_lookup,
    )

    # Wrap workflow in MetricsCollector for comprehensive metrics
    with MetricsCollector(
        client=client,
        processor_instance=unified_processor,
        track_workers=True,
        worker_tracking_interval=1.0,
    ) as collector:
        t0 = time.perf_counter()
        output, report = run_processor_workflow(
            config=validated_config,
            output_manager=output_manager,
            metadata_lookup=metadata_lookup,
            workitems=workitems,
            executor=DaskExecutor(client=client, treereduction=8, retries=0),
            schema=NanoAODSchema,
            skipbadfiles=None
        )
        t1 = time.perf_counter()

        # Extract chunk metrics from output (injected by @track_metrics decorator)
        collector.extract_metrics_from_output(output)

        # Set coffea report for aggregation
        collector.set_coffea_report(report)

    # Get aggregated metrics after context exits
    metrics = collector.get_metrics()
    tracking_data = collector.tracking_data
    span_metrics = getattr(collector, 'span_metrics', None)

print(f"✅ Processor workflow complete in {t1-t0:.1f} seconds!")

# Print summary
print(f"Total events processed: {output.get('processed_events', 0):,}")
print(f"Events after skim: {output.get('skimmed_events', 0):,}")
# Out:
# Processing 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41345/41345 [ 0:15:40 < 0:00:00 | 35.3 chunk/s ]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 2026-05-14 22:33:23.821 INFO:intccms.analysis.processors:Postprocessing complete: 6140264329 total events
# 2026-05-14 22:33:23.823 INFO:intccms.utils.output.histograms:Histograms written to pickle: /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/histograms/processor_histograms.pkl
# 2026-05-14 22:33:23.823 INFO:intccms.analysis.processors:Saved processor histograms (pickle) to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/histograms/processor_histograms.pkl
# 2026-05-14 22:33:23.850 INFO:intccms.utils.output.histograms:Histograms written to ROOT file: /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/histograms/histograms.root
# 2026-05-14 22:33:23.851 INFO:intccms.analysis.processors:Saved processor histograms (ROOT) to /home/cms-jovyan/intc/integration-challenge/cms/example_cms/outputs/histograms/histograms.root
# 2026-05-14 22:33:23.878 INFO:intccms.analysis.runner:Processor complete: 6,140,264,329 events processed, 261,814,893 events after skim
# ✅ Processor workflow complete in 946.1 seconds!
# Total events processed: 6,140,264,329
# Events after skim: 261,814,893

# %% [markdown]
# ## Performance Metrics (roastcoffea)
#
# This section displays comprehensive performance metrics collected during the workflow execution using `roastcoffea`.

# %% [markdown]
# ### Summary tables
#
# `roastcoffea` provides useful summary tables, formatted using `rich` and ready to be printed in a `rich` console.

# %%
# Import roastcoffea reporting and visualization
from rich.console import Console
from roastcoffea.export.reporter import (
    format_throughput_table,
    format_event_processing_table,
    format_resources_table,
    format_timing_table,
    format_fine_metrics_table,
)

console = Console()

print("\n📈 Throughput Metrics")
console.print(format_throughput_table(metrics))

print("\n⚡ Event Processing Metrics")
console.print(format_event_processing_table(metrics))

print("\n🖥️  Resource Utilization")
console.print(format_resources_table(metrics))

print("\n⏱️  Timing Breakdown")
console.print(format_timing_table(metrics))

# Fine-grained metrics from Dask Spans (CPU/IO breakdown)
print("\n🔬 Fine-Grained Metrics (CPU/IO Breakdown)")
console.print(format_fine_metrics_table(metrics))
# Out:
# 📈 Throughput Metrics
#                   Throughput Metrics
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metric                    ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Data Rate                 │ 5.79 Gbps (723.2 MB/s) │
# │ Total Bytes Read (Coffea) │ 637.33 GB              │
# │ Memory Read (Dask Spans)  │ 474.47 GB              │
# └───────────────────────────┴────────────────────────┘
# ⚡ Event Processing Metrics
#            Event Processing Metrics
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Metric                     ┃ Value         ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Total Events               │ 6,140,264,329 │
# │ Event Rate (Elapsed Time)  │ 6489.3 kHz    │
# │ Event Rate (Total CPU)     │ 174.4 kHz     │
# │ Event Rate (Core-Averaged) │ 14.4 kHz/core │
# │ Efficiency Ratio           │ 3720.8%       │
# └────────────────────────────┴───────────────┘
# 🖥️  Resource Utilization
#          Resource Utilization
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Metric                   ┃ Value   ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ Workers (Time-Averaged)  │ 452.0   │
# │ Peak Workers             │ 452     │
# │ Cores per Worker         │ 1.0     │
# │ Total Cores              │ 452     │
# │ Core Efficiency          │ 8.2%    │
# │ Speedup Factor           │ 37.2x   │
# │ Peak Memory (per worker) │ 1.52 GB │
# │ Avg Memory (per worker)  │ 1.12 GB │
# └──────────────────────────┴─────────┘
# ⏱️  Timing Breakdown
#          Timing Breakdown
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Metric             ┃ Value      ┃
# ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ Elapsed Time       │ 15m 46s    │
# │ Total CPU Time     │ 9h 46m 46s │
# │ Number of Chunks   │ 36,173     │
# │ Avg CPU Time/Chunk │ 1.0s       │
# └────────────────────┴────────────┘
# 🔬 Fine-Grained Metrics (CPU/IO Breakdown)
#           Fine Metrics (from Dask Spans)
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ Metric                           ┃ Value        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │ Processor CPU Time               │ 105h 52m 22s │
# │ Processor I/O & Waiting Time     │ 6h 20m 48s   │
# │   CPU %                          │ 94.3%        │
# │   I/O & Wait %                   │ 5.7%         │
# │ Dask Overhead CPU Time           │ 38.8s        │
# │ Dask Overhead I/O & Waiting Time │ 11.1s        │
# └──────────────────────────────────┴──────────────┘

# %% [markdown]
# ### Performance Visualizations
#
# `roastcoffea` provides API for useful plots that demonstrate various aspects of the processing.

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
from roastcoffea.visualization.plots import (
  plot_worker_count_timeline,
  plot_memory_utilization_mean_timeline,
  plot_memory_utilization_per_worker_timeline,
  plot_cpu_utilization_mean_timeline,
  plot_cpu_utilization_per_worker_timeline,
  plot_throughput_timeline,
  plot_per_task_cpu_io,
  plot_compression_ratio_distribution,
  plot_data_access_percentage,
  plot_runtime_distribution,
  plot_runtime_vs_events,
)

# %% [markdown]
# #### Timeline plots
# These are plots that offer a temporal view of the processing.

# %%
# ========================================================================
# Worker Count Over Time
# This shows how many workers were active as the processor was running
# ========================================================================
print("\nWorker Count Over Time")
try:
  fig, ax = plot_worker_count_timeline(tracking_data)
  plt.show()
except Exception as e:
  print(f"⚠️  Worker count plot unavailable: {e}")

# ========================================================================
# Data throughput over time
# This shows the rate at which data was being processed over time
# ========================================================================
print("\n📊 Data Throughput Over Time")
try:
  fig, ax = plot_throughput_timeline(metrics["chunk_info"], tracking_data)
  plt.show()
except Exception as e:
  print(f"⚠️  Throughput plot unavailable: {e}")


# ========================================================================
# Memory utilisation over time
# This shows the percentage of memory being utilised per worker and on average from all workers 
# ========================================================================
print("\n Memory Utilization (mean)")
try:
  fig, ax = plot_memory_utilization_mean_timeline(tracking_data)
  plt.show()
except Exception as e:
  print(f"⚠️  Memory plot unavailable: {e}")

print("\n Memory Utilization (per worker)")
try:
  fig, ax = plot_memory_utilization_per_worker_timeline(tracking_data)
  plt.show()
except Exception as e:
  print(f"⚠️  Memory plot unavailable: {e}")

# ========================================================================
# CPU utilisation over time
# This shows the percentage of CPU being utilised per worker and on average from all workers 
# ========================================================================
print("\n CPU Utilization (mean)")
try:
  fig, ax = plot_cpu_utilization_mean_timeline(tracking_data)
  plt.show()
except Exception as e:
  print(f"⚠️  CPU plot unavailable: {e}")

print("\n CPU Utilization (per worker)")
try:
  fig, ax = plot_cpu_utilization_per_worker_timeline(tracking_data)
  plt.show()
except Exception as e:
  print(f"⚠️  CPU plot unavailable: {e}")
# Out:
# Worker Count Over Time
# 📊 Data Throughput Over Time
#  Memory Utilization (mean)
#  Memory Utilization (per worker)
#  CPU Utilization (mean)
#  CPU Utilization (per worker)

# %% [markdown]
# #### Tasks breakdown
# These are plots demonstrating what different tasks wee being executed during processing. The information here is extracted using the `dask` spans API.

# %%
# ========================================================================
# CPU vs non-CPU time per task
# This shows how much time did each task spend doing cpu work vs non-cpu work
# ========================================================================
print("\n📊 Per-Task CPU vs Non-CPU Breakdown")
try:
  fig, ax = plot_per_task_cpu_io(span_metrics)
  plt.show()
except Exception as e:
  print(f"⚠️  CPU/IO plot unavailable: {e}")
# Out:
# 📊 Per-Task CPU vs Non-CPU Breakdown

# %% [markdown]
# #### Processor Statistics
# These are plots offering insights on what is going into the processor, what the processor is doing and how complex it is.

# %% [markdown]
# **Processor Inputs**

# %%
# Plot compression ratio distribution
try:
  fig, ax = plot_compression_ratio_distribution(metrics)
  plt.show()
  print("✅ Compression ratios show file compression efficiency")
except Exception as e:
  print(f"❌ Compression ratio plot unavailable: {e}")

# Plot bytes read percentage distribution
try:
  fig, ax = plot_data_access_percentage(metrics)
  plt.show()
  print("✅ Shows what % of each file's data was actually read")
except Exception as e:
  print(f"❌ Data access plot unavailable: {e}")
# Out:
# ❌ Compression ratio plot unavailable: No compression ratio data available
# ❌ Data access plot unavailable: No bytes read percentage data available

# %%
# Other useful information to complement the plots
# Branch coverage (if available)
if 'total_branches_read' in metrics:
  print(f"Branches read: {metrics['total_branches_read']}")
  print(f"Avg branches read %: {metrics.get('avg_branches_read_percent', 0):.1f}%")
  print(f"Avg bytes read %: {metrics.get('avg_bytes_read_percent', 0):.1f}%")

# Compression ratios (if available)
if 'compression_ratios' in metrics and metrics['compression_ratios']:
  import numpy as np
  ratios = metrics['compression_ratios']
  print(f"Compression ratio: {np.mean(ratios):.2f} (avg)")

# Chunk metrics (if available)
if 'chunk_metrics' in metrics and metrics['chunk_metrics']:
  print(f"Number of chunks: {len(metrics['chunk_metrics'])}")
# Out:
# Branches read: 30
# Avg branches read %: 0.0%
# Avg bytes read %: 0.0%

# %% [markdown]
# **Runtime**

# %%
# Plot chunk runtime distribution
try:
  fig, ax = plot_runtime_distribution(metrics.get('raw_chunk_metrics'))
  plt.show()
  print("✅ Runtime distribution shows processing time variability")
except Exception as e:
  print(f"❌ Runtime distribution unavailable: {e}")

# Plot runtime vs number of events
try:
  fig, ax = plot_runtime_vs_events(metrics.get('raw_chunk_metrics'))
  plt.show()
  print("✅ Runtime vs events shows scaling behavior")
except Exception as e:
  print(f"❌ Runtime vs events plot unavailable: {e}")
# Out:
# ✅ Runtime distribution shows processing time variability
# ✅ Runtime vs events shows scaling behavior

# %% [markdown]
# ### And many more!
#
# See https://roastcoffea.readthedocs.io/en/latest/ for more information!
